# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesse-Goldie/MMA_3001_Notes/blob/Jesse/Jesse-Practical/Flowchart-W1/FLowCharW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# '''mermaid
#
# rt: matmul(A, B)"]) --> Dims["m = len(A)<br>n = len(A[0])<br>p = len(B[0])"]
#     Dims --> InitC["Initialize C as an m × p zero matrix"]
#     InitC --> IStart["Set i = 0"]
#     IStart --> ICheck{"i &lt; m?"}
#     ICheck -- No --> Return["Return C"]
#     ICheck -- Yes --> JStart["Set j = 0"]
#     JStart --> JCheck{"j &lt; p?"}
#     IIncrement["After each i iteration:<br>i = i + 1"] --> ICheck
#     JCheck -- Yes --> SInit["Set s = 0"]
#     SInit --> KStart["Set k = 0"]
#     KStart --> KCheck{"k &lt; n?"}
#     KCheck -- Yes --> Multiply["s = s + A[i][k] × B[k][j]"]
#     Multiply --> KIncrement["After each k iteration:<br>k = k + 1"]
#     KIncrement --> KCheck
#     KCheck -- No --> Assign["C[i][j] = s"]
#     Assign --> JIncrement["After each j iteration:<br>j = j + 1"]
#     JIncrement --> JCheck
#     Return --> End(["End"])
#     JCheck -- No --> IIncrement
#
#      Start:::startEnd
#      Dims:::input
#      InitC:::input
#      IStart:::loop
#      ICheck:::decision
#      JStart:::loop
#      JCheck:::decision
#      IIncrement:::increment
#      SInit:::compute
#      KStart:::loop
#      KCheck:::decision
#      Multiply:::compute
#      KIncrement:::increment
#      Assign:::compute
#      JIncrement:::increment
#      End:::startEnd
#     classDef startEnd fill:#f0fdf4,stroke:#4ade80
#     classDef input fill:#f0f9ff,stroke:#38bdf8
#     classDef loop fill:#f5f3ff,stroke:#a78bfa
#     classDef decision fill:#fff7ed,stroke:#fb923c
#     classDef compute fill:#fef2f2,stroke:#f87171
#     classDef increment fill:#ecfeff,stroke:#22d3ee
#
#  '''

# %%
# !pip install mmdc

import mmdc

mermaid_code = """
rt: matmul(A, B)"]) --> Dims["m = len(A)
n = len(A[0])
p = len(B[0])"] Dims --> InitC["Initialize C as an m × p zero matrix"] InitC --> IStart["Set i = 0"] IStart --> ICheck{"i < m?"} ICheck -- No --> Return["Return C"] ICheck -- Yes --> JStart["Set j = 0"] JStart --> JCheck{"j < p?"} IIncrement["After each i iteration:
i = i + 1"] --> ICheck JCheck -- Yes --> SInit["Set s = 0"] SInit --> KStart["Set k = 0"] KStart --> KCheck{"k < n?"} KCheck -- Yes --> Multiply["s = s + A[i][k] × B[k][j]"] Multiply --> KIncrement["After each k iteration:
k = k + 1"] KIncrement --> KCheck KCheck -- No --> Assign["C[i][j] = s"] Assign --> JIncrement["After each j iteration:
j = j + 1"] JIncrement --> JCheck Return --> End(["End"]) JCheck -- No --> IIncrement

 Start:::startEnd
 Dims:::input
 InitC:::input
 IStart:::loop
 ICheck:::decision
 JStart:::loop
 JCheck:::decision
 IIncrement:::increment
 SInit:::compute
 KStart:::loop
 KCheck:::decision
 Multiply:::compute
 KIncrement:::increment
 Assign:::compute
 JIncrement:::increment
 End:::startEnd
classDef startEnd fill:#f0fdf4,stroke:#4ade80
classDef input fill:#f0f9ff,stroke:#38bdf8
classDef loop fill:#f5f3ff,stroke:#a78bfa
classDef decision fill:#fff7ed,stroke:#fb923c
classDef compute fill:#fef2f2,stroke:#f87171
classDef increment fill:#ecfeff,stroke:#22d3ee
"""
